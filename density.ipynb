# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

my_df = pd.DataFrame(randn(500,4), columns=['Mon', 'Tues', 'Wed', 'Thurs'])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    0.990073  1.131609  0.529492  0.656627
# 1   -0.849172 -0.304365  0.923391 -0.013254
# 2   -0.424347  0.470228 -1.498742 -0.173786
# 3    0.808433 -1.898025 -0.478330 -0.456910
# 4    0.604636  0.553978  0.986392 -0.651367
# ..        ...       ...       ...       ...
# 495  1.094352  0.149060 -0.245175 -3.082938
# 496 -0.876215  1.571254 -1.105998  0.744174
# 497  0.447344  0.158837 -1.783936 -0.320471
# 498  0.066934  0.518984  0.981040 -0.754853
# 499  0.614920 -1.555403  0.810119  0.557658
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
my_df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
my_df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
my_df.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
my_df['Mon'].plot.kde(alpha=0.4, lw=4)
# Out:
# <Axes: ylabel='Density'>

# %%
my_df['Mon'].plot.kde(alpha=0.4, lw=4, grid=True)
# Out:
# <Axes: ylabel='Density'>

# %%
my_df['Mon'].plot.kde(alpha=0.4, lw=4, title='')
