# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# Create Dataframe
my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    1.062185  0.467749 -2.000221  0.847036
# 1   -0.938925 -0.017619 -0.034585 -0.222400
# 2   -0.762381 -0.352508  0.409409  0.642608
# 3   -0.132659  0.496242 -1.631361 -0.369330
# 4    2.157022 -0.568556  0.023686  0.610935
# ..        ...       ...       ...       ...
# 495  1.537226  2.617743 -0.476571 -0.320633
# 496  0.468658  0.178405 -2.026300 -0.104585
# 497  0.799865 -1.046169 -0.781767 -0.690250
# 498 -0.077538 -0.210675  1.364402 -0.054216
# 499 -1.907174 -0.289449 -0.898355  1.568603
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind="scatter", x="Mon", y="Tues", c="Wed")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot(kind="scatter", x="Mon", y="Tues", c="Wed", cmap='magma')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot(kind='scatter', x='Mon', y='Tues', s=my_df['Wed']*100)
# Out:
# D:\Python-Projects\mydata\virt\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df['Wed']*200, alpha=0.4)
# Out:
# D:\Python-Projects\mydata\virt\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot(kind='scatter', x='Mon', y='Tues', s=my_df['Wed']*200, alpha=0.4, title='Scatter Plot')
# Out:
# D:\Python-Projects\mydata\virt\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: title={'center': 'Scatter Plot'}, xlabel='Mon', ylabel='Tues'>
