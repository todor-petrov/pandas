# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0   -0.105798 -1.004860 -1.314018  0.642914
# 1   -0.050785  1.494253 -0.545987 -0.117806
# 2    0.323574 -0.743224 -1.439348 -0.580691
# 3    0.585934  2.837337  1.510985  0.031405
# 4   -1.711211  1.179589  0.705703 -2.097811
# ..        ...       ...       ...       ...
# 495  1.171003 -1.175619  1.072627 -1.521381
# 496  0.417498  0.040062  1.451139 -0.900838
# 497  1.628223 -0.684103 -1.385875 -0.419675
# 498  0.219391  0.178858  0.368043 -0.022119
# 499  1.380947 -0.794588  0.496663  1.601802
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind='box')
# Out:
# <Axes: >

# %%
my_df.plot(kind='box', figsize=(10, 5))
# Out:
# <Axes: >

# %%
my_df.plot(kind='box', cmap='jet')
# Out:
# <Axes: >

# %%
my_df.plot(kind='box', legend=True)
# Out:
# <Axes: >

# %%
my_df.plot(kind='box', title='Box Plot')
# Out:
# <Axes: title={'center': 'Box Plot'}>

# %%
my_df.plot.box()
# Out:
# <Axes: >

# %%
my_df.plot(kind='box'grid=True)
# Out:
#   Cell In[9], line 1
#     my_df.plot(kind='box'grid=True)
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
