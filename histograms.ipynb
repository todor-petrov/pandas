# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline
my_df = pd.DataFrame(randn(100, 4), columns=['Mon', 'Tues', 'Wed', 'Thur'])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0  -0.351527 -0.099114 -0.255434 -0.044882
# 1   1.674243 -0.039103  0.134732 -1.450561
# 2   0.784201 -0.798145  0.497457  1.217845
# 3  -0.270485  0.216131  0.687129  0.728729
# 4   0.378381  0.828112  1.202778  1.090883
# ..       ...       ...       ...       ...
# 95  0.411344  1.893285  0.043004 -0.055140
# 96 -0.530456  2.301397  0.339944 -1.234343
# 97  0.154522  0.305635  0.608425 -0.701409
# 98  0.966834  1.155976  1.104274  0.297594
# 99  0.666103  0.995587  0.709487 -0.115088
#
# [100 rows x 4 columns]

# %%
my_df['Wed'].hist()
# Out:
# <Axes: >

# %%
my_df['Wed'].hist(bins=20)
# Out:
# <Axes: >

# %%
my_df['Wed'].plot(kind='hist', bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
my_df['Wed'].plot(kind='hist', bins=20, grid=False)
