# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

my_df = pd.DataFrame(randn(500,4), columns=["Mon", "Tues", "Wed", "Thurs"])
my_df
# Out:
#           Mon      Tues       Wed     Thurs
# 0    0.301547 -0.212077 -0.289369  0.083031
# 1   -0.269141  1.745156  1.214922 -0.707442
# 2   -1.027313  0.142144 -0.655412 -0.739930
# 3   -0.297335 -1.186606  1.615112 -0.221184
# 4    0.142552 -1.156698  0.537258 -1.310115
# ..        ...       ...       ...       ...
# 495 -0.643280  2.574032 -1.528604  0.635018
# 496  0.122228  0.798807 -0.513246  0.352538
# 497  0.529421 -2.919359 -0.832848 -1.406865
# 498  1.221656 -2.445127  0.390573  1.860528
# 499  2.126582 -1.558637  0.748626 -1.452756
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind='hexbin', x='Mon', y='Tues')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot(kind='hexbin', x='Mon', y='Tues', gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot(kind='hexbin', x='Mon', y='Tues', gridsize=10, cmap='Wistia')
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot.hexbin(x='Mon', y='Tues', C='Wed', gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot.hexbin(x='Mon', y='Tues', C='Wed', gridsize=10, title='Hex Plot')
# Out:
# <Axes: title={'center': 'Hex Plot'}, xlabel='Mon', ylabel='Tues'>

# %%
my_df.plot.hexbin(x='Mon', y='Tues', C='Wed', gridsize=10, title='Hex Plot', grid=True)
# Out:
# <Axes: title={'center': 'Hex Plot'}, xlabel='Mon', ylabel='Tues'>
